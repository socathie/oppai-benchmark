# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# os.environ['CUDA_VISIBLE_DEVICES'] = ''

import tensorflow as tf
import numpy as np
import pandas as pd

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras_vggface.vggface import VGGFace

tf.keras.utils.set_random_seed(321)

# %%
# read peopleDevTrain.csv and peopleDevTest.csv
train = pd.read_csv('peopleDevTrain.csv')
test = pd.read_csv('peopleDevTest.csv')

# remove rows with empty 'cropped' column
train = train[train['cropped'].notna()]
test = test[test['cropped'].notna()]

# %%
# list of image files in "cropped" column, put into data loader
datagen = ImageDataGenerator(rescale=1./255)
train_loader = datagen.flow_from_dataframe(train, x_col='cropped', target_size=(224, 224), batch_size=32, class_mode='input', seed=42)

val_loader = datagen.flow_from_dataframe(test, x_col='cropped', target_size=(224, 224), batch_size=32, class_mode='input', seed=42)
# Out:
# Found 9482 validated image filenames.
# Found 3689 validated image filenames.

# %%
model = VGGFace(model='vgg16')

# %%
encoder = tf.keras.Model(inputs=model.input, outputs=model.get_layer('pool2').output)
encoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1_1 (Conv2D)            (None, 224, 224, 64)      1792
#
#  conv1_2 (Conv2D)            (None, 224, 224, 64)      36928
#
#  pool1 (MaxPooling2D)        (None, 112, 112, 64)      0
#
#  conv2_1 (Conv2D)            (None, 112, 112, 128)     73856
#
#  conv2_2 (Conv2D)            (None, 112, 112, 128)     147584
#
#  pool2 (MaxPooling2D)        (None, 56, 56, 128)       0
#
# =================================================================
# Total params: 260,160
# Trainable params: 260,160
# Non-trainable params: 0
# _________________________________________________________________

# %%
# build decoder
latent = tf.keras.Input(shape=encoder.output.shape[1:])

x = tf.keras.layers.UpSampling2D((2, 2))(latent)
x = tf.keras.layers.Conv2DTranspose(128, (3, 3), padding='same', activation='relu')(x)
x = tf.keras.layers.Conv2DTranspose(128, (3, 3), padding='same', activation='relu')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2DTranspose(64, (3, 3), padding='same', activation='relu')(x)
x = tf.keras.layers.Conv2DTranspose(64, (3, 3), padding='same', activation='relu')(x)
x = tf.keras.layers.Conv2DTranspose(3, (3, 3), padding='same', activation='sigmoid')(x)

decoder = tf.keras.Model(inputs=latent, outputs=x)

decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 56, 56, 128)]     0
#
#  up_sampling2d (UpSampling2D  (None, 112, 112, 128)    0
#  )
#
#  conv2d_transpose (Conv2DTra  (None, 112, 112, 128)    147584
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 112, 112, 128)    147584
#  ranspose)
#
#  up_sampling2d_1 (UpSampling  (None, 224, 224, 128)    0
#  2D)
#
#  conv2d_transpose_2 (Conv2DT  (None, 224, 224, 64)     73792
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 224, 224, 64)     36928
#  ranspose)
#
#  conv2d_transpose_4 (Conv2DT  (None, 224, 224, 3)      1731
#  ranspose)
#
# =================================================================
# Total params: 407,619
# Trainable params: 407,619
# Non-trainable params: 0
# _________________________________________________________________

# %%
# add preprocessing layers before encoder
image_input = tf.keras.Input(shape=(224, 224, 3))

# scale back to 0-255
x = tf.keras.layers.Lambda(lambda x: x * 255)(image_input)
# change rgb to bgr
x = tf.keras.layers.Lambda(lambda x: x[..., ::-1])(x)
# subtract mean
x = tf.keras.layers.Lambda(lambda x: x - [93.5940, 104.7624, 129.1863])(x)

preprocessor = tf.keras.Model(inputs=image_input, outputs=x)

# %%
# set encoder as non-trainable
for layer in encoder.layers:
    layer.trainable = False

model = tf.keras.Sequential([preprocessor, encoder, decoder])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_2 (Functional)        (None, 224, 224, 3)       0
#
#  model (Functional)          (None, 56, 56, 128)       260160
#
#  model_1 (Functional)        (None, 224, 224, 3)       407619
#
# =================================================================
# Total params: 667,779
# Trainable params: 407,619
# Non-trainable params: 260,160
# _________________________________________________________________

# %%
# train
model.compile(optimizer='adam', loss='binary_crossentropy')
model.fit(train_loader, validation_data=val_loader, epochs=100)
# Out:
# Epoch 1/100
# 297/297 [==============================] - 65s 177ms/step - loss: 8.0991 - val_loss: 0.6379
# Epoch 2/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.6154 - val_loss: 0.5996
# Epoch 3/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5944 - val_loss: 0.5889
# Epoch 4/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5865 - val_loss: 0.5824
# Epoch 5/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5824 - val_loss: 0.5797
# Epoch 6/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5797 - val_loss: 0.5775
# Epoch 7/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5782 - val_loss: 0.5772
# Epoch 8/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5773 - val_loss: 0.5752
# Epoch 9/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5763 - val_loss: 0.5746
# Epoch 10/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5757 - val_loss: 0.5740
# Epoch 11/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5753 - val_loss: 0.5734
# Epoch 12/100
# 297/297 [==============================] - 46s 157ms/step - loss: 0.5748 - val_loss: 0.5731
# Epoch 13/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5748 - val_loss: 0.5743
# Epoch 14/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5742 - val_loss: 0.5724
# Epoch 15/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5741 - val_loss: 0.5726
# Epoch 16/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5737 - val_loss: 0.5724
# Epoch 17/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5738 - val_loss: 0.5720
# Epoch 18/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5735 - val_loss: 0.5723
# Epoch 19/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5734 - val_loss: 0.5718
# Epoch 20/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5733 - val_loss: 0.5720
# Epoch 21/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5733 - val_loss: 0.5722
# Epoch 22/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5733 - val_loss: 0.5717
# Epoch 23/100
# 297/297 [==============================] - 48s 161ms/step - loss: 0.5731 - val_loss: 0.5719
# Epoch 24/100
# 297/297 [==============================] - 47s 159ms/step - loss: 0.5731 - val_loss: 0.5716
# Epoch 25/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5730 - val_loss: 0.5716
# Epoch 26/100
# 297/297 [==============================] - 48s 162ms/step - loss: 0.5729 - val_loss: 0.5714
# Epoch 27/100
# 297/297 [==============================] - 48s 160ms/step - loss: 0.5729 - val_loss: 0.5717
# Epoch 28/100
# 297/297 [==============================] - 47s 159ms/step - loss: 0.5728 - val_loss: 0.5724
# Epoch 29/100
# 297/297 [==============================] - 47s 160ms/step - loss: 0.5729 - val_loss: 0.5724
# Epoch 30/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5728 - val_loss: 0.5716
# Epoch 31/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5727 - val_loss: 0.5713
# Epoch 32/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5726 - val_loss: 0.5712
# Epoch 33/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5727 - val_loss: 0.5713
# Epoch 34/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5726 - val_loss: 0.5711
# Epoch 35/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5726 - val_loss: 0.5713
# Epoch 36/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5726 - val_loss: 0.5712
# Epoch 37/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5726 - val_loss: 0.5712
# Epoch 38/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5725 - val_loss: 0.5711
# Epoch 39/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5724 - val_loss: 0.5710
# Epoch 40/100
# 297/297 [==============================] - 46s 157ms/step - loss: 0.5725 - val_loss: 0.5710
# Epoch 41/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5726 - val_loss: 0.5709
# Epoch 42/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5724 - val_loss: 0.5713
# Epoch 43/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5723 - val_loss: 0.5710
# Epoch 44/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5725 - val_loss: 0.5718
# Epoch 45/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5723 - val_loss: 0.5716
# Epoch 46/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5724 - val_loss: 0.5716
# Epoch 47/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5725 - val_loss: 0.5711
# Epoch 48/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5722 - val_loss: 0.5711
# Epoch 49/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5724 - val_loss: 0.5708
# Epoch 50/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5722 - val_loss: 0.5708
# Epoch 51/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5722 - val_loss: 0.5712
# Epoch 52/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5724 - val_loss: 0.5713
# Epoch 53/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5723 - val_loss: 0.5711
# Epoch 54/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5723 - val_loss: 0.5710
# Epoch 55/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5721 - val_loss: 0.5710
# Epoch 56/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5722 - val_loss: 0.5712
# Epoch 57/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5723 - val_loss: 0.5709
# Epoch 58/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5722 - val_loss: 0.5707
# Epoch 59/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5722 - val_loss: 0.5710
# Epoch 60/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5721 - val_loss: 0.5711
# Epoch 61/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5723 - val_loss: 0.5712
# Epoch 62/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5722 - val_loss: 0.5707
# Epoch 63/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5721 - val_loss: 0.5706
# Epoch 64/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5720 - val_loss: 0.5707
# Epoch 65/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5722 - val_loss: 0.5710
# Epoch 66/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5721 - val_loss: 0.5706
# Epoch 67/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5723 - val_loss: 0.5706
# Epoch 68/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5722 - val_loss: 0.5709
# Epoch 69/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5722 - val_loss: 0.5707
# Epoch 70/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5721 - val_loss: 0.5706
# Epoch 71/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5722 - val_loss: 0.5709
# Epoch 72/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5721 - val_loss: 0.5706
# Epoch 73/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5721 - val_loss: 0.5708
# Epoch 74/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5720 - val_loss: 0.5706
# Epoch 75/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5721 - val_loss: 0.5709
# Epoch 76/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5721 - val_loss: 0.5707
# Epoch 77/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5721 - val_loss: 0.5708
# Epoch 78/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5723 - val_loss: 0.5708
# Epoch 79/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5722 - val_loss: 0.5711
# Epoch 80/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5721 - val_loss: 0.5711
# Epoch 81/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5723 - val_loss: 0.5707
# Epoch 82/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5721 - val_loss: 0.5705
# Epoch 83/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5720 - val_loss: 0.5709
# Epoch 84/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5722 - val_loss: 0.5706
# Epoch 85/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5722 - val_loss: 0.5705
# Epoch 86/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5722 - val_loss: 0.5710
# Epoch 87/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5722 - val_loss: 0.5710
# Epoch 88/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5721 - val_loss: 0.5710
# Epoch 89/100
# 297/297 [==============================] - 46s 157ms/step - loss: 0.5721 - val_loss: 0.5709
# Epoch 90/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5721 - val_loss: 0.5707
# Epoch 91/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5721 - val_loss: 0.5714
# Epoch 92/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5724 - val_loss: 0.5706
# Epoch 93/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5720 - val_loss: 0.5711
# Epoch 94/100
# 297/297 [==============================] - 46s 156ms/step - loss: 0.5722 - val_loss: 0.5709
# Epoch 95/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5723 - val_loss: 0.5705
# Epoch 96/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5722 - val_loss: 0.5709
# Epoch 97/100
# 297/297 [==============================] - 47s 158ms/step - loss: 0.5721 - val_loss: 0.5707
# Epoch 98/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5720 - val_loss: 0.5708
# Epoch 99/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5735 - val_loss: 0.5716
# Epoch 100/100
# 297/297 [==============================] - 47s 157ms/step - loss: 0.5729 - val_loss: 0.5718

# %%
import matplotlib.pyplot as plt

# show 5 train images and their reconstructions
for i in range(5):
    img = train_loader[i][0][0]
    rec = model.predict(np.expand_dims(img, axis=0))[0]
    plt.subplot(2, 5, i+1)
    plt.imshow(img)
    plt.axis('off')
    plt.subplot(2, 5, i+6)
    plt.imshow(rec)
    plt.axis('off')
# Out:
# 1/1 [==============================] - 0s 476ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step

# %%
# show 5 test images and their reconstructions
for i in range(5):
    img = val_loader[i][0][0]
    rec = model.predict(np.expand_dims(img, axis=0))[0]
    plt.subplot(2, 5, i+1)
    plt.imshow(img)
    plt.axis('off')
    plt.subplot(2, 5, i+6)
    plt.imshow(rec)
    plt.axis('off')
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
